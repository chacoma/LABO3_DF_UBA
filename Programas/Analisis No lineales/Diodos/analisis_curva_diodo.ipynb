# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ### Barrido de tensión

# %%
df = pd.read_csv('datos/barrido_tension.txt', 
                 sep='\t|,',  
                 engine='python',  
                 skiprows=1, 
                 names=['Vf', 'Vd', 'I'],
                 dtype='float'
)

df.head()
# Out:
#      Vf    Vd             I
# 0  0.00  0.00  0.000000e+00
# 1  0.01  0.01 -1.386623e-14
# 2  0.02  0.02 -3.166790e-14
# 3  0.03  0.03 -5.189526e-14
# 4  0.04  0.04 -7.694991e-14

# %%
#plot
fig,ax = plt.subplots(figsize=(4,3))

ax.scatter( df["Vd"],-df["I"] , label="")

ax.set_xlabel("$V_d$ [Hz]")
ax.set_ylabel("$I$ ")
ax.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ### Rampa

# %%
df2 = pd.read_csv('datos/rampa.txt', 
                 sep='\t|,',  
                 engine='python',  
                 skiprows=0, 
                 dtype='float'
)

df2.head()
# Out:
#        time       Vf            VR        Vd
# 0  0.000000  0.00000  0.000000e+00  0.000000
# 1  0.000166  0.23175  4.470348e-08  0.231750
# 2  0.000216  0.30175  5.066395e-07  0.301750
# 3  0.000266  0.37175  7.420778e-06  0.371743
# 4  0.000316  0.44175  1.099110e-04  0.441640

# %%
R=100

#plot
fig,ax = plt.subplots(figsize=(4,3))

ax.plot( df2["time"],df2["Vf"] , label="V fuente")

ax.plot( df2["time"],df2["VR"] , label="V resist")

ax.plot( df2["time"],df2["Vd"] , label="V diodo")

ax.set_xlabel("$t$ [s]")
ax.set_ylabel("$V$ [V]")
ax.legend()
plt.show()
